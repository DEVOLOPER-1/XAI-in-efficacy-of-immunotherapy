# %%
import pandas as pd

# %%
features = [
    "ENSG00000178458.5",
    "ENSG00000168078.10",
    "ENSG00000224462.2",
    "ENSG00000231503.4",
    "ENSG00000143590.14",
    "ENSG00000173083.15",
    "ENSG00000119411.11",
    "ENSG00000144214.10",
    "ENSG00000176890.16",
    "ENSG00000213218.11",
    "ENSG00000072310.17",
    "ENSG00000138180.16",
    "ENSG00000287158.1",
    "ENSG00000250920.3",
    "ENSG00000288535.1",
    "ENSG00000164466.13",
    "ENSG00000187961.14",
    "ENSG00000116761.12",
    "ENSG00000177689.10",
    "ENSG00000166049.11",
    "ENSG00000251577.5",
]
len(features)
# Out:
# 21

# %%
PATH = "../../../data/processed/stad_rna.parquet"

# %%
df = pd.read_parquet(PATH)
df.head(1)
# Out:
#      PATIENT_ID  TMB  ENSG00000000003.15  ENSG00000000005.6  \
# 0  TCGA-3M-AB46  5.6             19.5851             0.1442
#
#    ENSG00000000419.13  ENSG00000000457.14  ENSG00000000460.17  \
# 0            103.8039              4.9516              3.8857
#
#    ENSG00000000938.13  ENSG00000000971.16  ENSG00000001036.14  ...  \
# 0              1.2945              3.1318             80.3819  ...
#
#    ENSG00000288658.1  ENSG00000288659.1  ENSG00000288660.1  ENSG00000288662.1  \
# 0             0.3074                0.0             4.8511             3.0403
#
#    ENSG00000288663.1  ENSG00000288667.1  ENSG00000288669.1  ENSG00000288670.1  \
# 0             0.2187             4.4857                0.0             5.5691
#
#    ENSG00000288674.1  ENSG00000288675.1
# 0             0.0095             0.5972
#
# [1 rows x 58231 columns]

# %%
df[["PATIENT_ID", "TMB"]+features].to_parquet("../../../data/processed/stad_rna_selected:21.parquet")
